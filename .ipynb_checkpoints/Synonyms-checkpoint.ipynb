# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('ocean_traits.csv')

# %%
dataset
# Out:
#           Openness Conscintiousness  Extraversion      Agreeableness  \
# 0      Imaginative       Thoughtful      Cheerful        Trustworthy
# 1       Insightful    Goal-oriented      Sociable           Altruism
# 2          Curious        Ambitious     Talkative               Kind
# 3         Creative        Organised     Assertive       Affectionate
# 4        Outspoken          Mindful      Outgoing        Cooperative
# 5  Straightforward         Vigilant     Energetic         Empathetic
# 6           Direct          Control   Extroverted             Modest
# 7        Receptive      Disciplined      Friendly        Sympathetic
# 8      Open-minded         Reliable  Enthusiastic          Compliant
# 9      Adventurous      Responsible     Outspoken  Tender-mindedness
#
#           Neuroticism
# 0                Calm
# 1      Strong hearted
# 2           Collected
# 3            Balanced
# 4            Peaceful
# 5            Tranquil
# 6       Strong-willed
# 7  Emotionally Stable
# 8              Serene
# 9           Resilient

# %%
import nltk
from nltk.corpus import wordnet

def synonym_extractor(phrase):
     synonyms = []

     for syn in wordnet.synsets(phrase):
          for l in syn.lemmas():
               synonyms.append(l.name())
     print('These are synonyms = ',set(synonyms),'\n\n')
     
     return(set(synonyms))

# %%
column_names = {}

Column = set()
for j in range(len(dataset.columns)):
    column_wise_synonyms = []
    for i in range(len(dataset.iloc[:, 0].values)):
        print('\n')
        print(dataset.iloc[:, 0].values[i],":- ")
        for element in synonym_extractor(dataset.iloc[:, j].values[i]):
            column_wise_synonyms.append(element)
    column_wise_synonyms_set = list(set(column_wise_synonyms))
    print('/////////////////////////////////////////////////////////////////////////')
    print(f"this is {dataset.columns[j]}  synonyms set:",column_wise_synonyms_set)
    print('/////////////////////////////////////////////////////////////////////////')
    while len(column_wise_synonyms_set) != 73:
        column_wise_synonyms_set.append(np.nan)
#     column_names.append(column_wise_synonyms_set)
    column_names.update({dataset.columns[j]:column_wise_synonyms_set})
# Out:
# Imaginative :-
# These are synonyms =  {'inventive', 'imaginative'}
#
#
#
#
# Insightful :-
# These are synonyms =  {'insightful'}
#
#
#
#
# Curious :-
# These are synonyms =  {'queer', 'rum', 'odd', 'funny', 'singular', 'peculiar', 'rummy', 'curious'}
#
#
#
#
# Creative :-
# These are synonyms =  {'originative', 'creative'}
#
#
#
#
# Outspoken :-
# These are synonyms =  {'point-blank', 'plainspoken', 'outspoken', 'candid', 'frank', 'straight-from-the-shoulder', 'vocal', 'blunt', 'free-spoken', 'forthright'}
#
#
#
#
# Straightforward :-
# These are synonyms =  {'straight', 'aboveboard', 'straightforward', 'square'}
#
#
#
#
# Direct :-
# These are synonyms =  {'place', 'orchestrate', 'point', 'head', 'organise', 'conduct', 'manoeuver', 'engineer', 'directly', 'lead', 'organize', 'steer', 'channelize', 'direct', 'mastermind', 'guide', 'take_aim', 'address', 'lineal', 'verbatim', 'channelise', 'target', 'calculate', 'train', 'unmediated', 'straight', 'maneuver', 'send', 'take', 'manoeuvre', 'aim'}
#
#
#
#
# Receptive :-
# These are synonyms =  {'centripetal', 'open', 'sensory', 'receptive'}
#
#
#
#
# Open-minded :-
# These are synonyms =  {'open-minded'}
#
#
#
#
# Adventurous :-
# These are synonyms =  {'adventurous', 'adventuresome'}
#
#
# /////////////////////////////////////////////////////////////////////////
# this is Openness  synonyms set: ['place', 'odd', 'candid', 'orchestrate', 'creative', 'point', 'head', 'organise', 'imaginative', 'straight-from-the-shoulder', 'open', 'aboveboard', 'originative', 'rum', 'inventive', 'conduct', 'manoeuver', 'adventuresome', 'engineer', 'directly', 'singular', 'lead', 'organize', 'steer', 'channelize', 'open-minded', 'receptive', 'direct', 'mastermind', 'guide', 'take_aim', 'address', 'lineal', 'verbatim', 'square', 'channelise', 'target', 'calculate', 'rummy', 'insightful', 'free-spoken', 'straight', 'train', 'unmediated', 'maneuver', 'point-blank', 'plainspoken', 'centripetal', 'queer', 'sensory', 'send', 'outspoken', 'take', 'adventurous', 'manoeuvre', 'frank', 'funny', 'straightforward', 'peculiar', 'vocal', 'blunt', 'curious', 'forthright', 'aim']
# /////////////////////////////////////////////////////////////////////////
#
#
# Imaginative :-
# These are synonyms =  {'attentive', 'serious-minded', 'heedful', 'thoughtful', 'paying_attention'}
#
#
#
#
# Insightful :-
# These are synonyms =  set()
#
#
#
#
# Curious :-
# These are synonyms =  {'challenging', 'ambitious'}
#
#
#
#
# Creative :-
# These are synonyms =  {'organised', 'unionise', 'organized', 'organize', 'direct', 'mastermind', 'orchestrate', 'unionized', 'devise', 'engineer', 'get_up', 'organise', 'machinate', 'unionize', 'prepare', 'coordinate', 'unionised', 'form'}
#
#
#
#
# Outspoken :-
# These are synonyms =  {'mindful', 'aware'}
#
#
#
#
# Straightforward :-
# These are synonyms =  {'wakeful', 'open-eyed', 'argus-eyed', 'vigilant'}
#
#
#
#
# Direct :-
# These are synonyms =  {'controller', 'moderate', 'ascendency', 'check', 'assure', 'hold', 'keep_in_line', 'ascertain', 'control_condition', 'master', 'command', 'insure', 'contain', 'control', 'ascendance', 'verify', 'manipulate', 'ensure', 'ascendence', 'operate', 'ascendancy', 'hold_in', 'dominance', 'see', 'curb', 'see_to_it', 'restraint', 'mastery'}
#
#
#
#
# Receptive :-
# These are synonyms =  {'condition', 'discipline', 'correct', 'check', 'disciplined', 'sort_out', 'train'}
#
#
#
#
# Open-minded :-
# These are synonyms =  {'reliable', 'honest', 'true', 'dependable', 'authentic'}
#
#
#
#
# Adventurous :-
# These are synonyms =  {'responsible_for', 'responsible', 'creditworthy'}
#
#
# /////////////////////////////////////////////////////////////////////////
# this is Conscintiousness  synonyms set: ['organised', 'controller', 'moderate', 'condition', 'ascendency', 'organized', 'orchestrate', 'check', 'assure', 'hold', 'keep_in_line', 'disciplined', 'reliable', 'sort_out', 'organise', 'open-eyed', 'aware', 'machinate', 'ascertain', 'prepare', 'control_condition', 'mindful', 'unionise', 'challenging', 'master', 'discipline', 'command', 'insure', 'unionized', 'contain', 'control', 'devise', 'vigilant', 'engineer', 'ascendance', 'ambitious', 'verify', 'manipulate', 'honest', 'true', 'dependable', 'unionize', 'authentic', 'creditworthy', 'organize', 'heedful', 'unionised', 'form', 'direct', 'mastermind', 'attentive', 'correct', 'ensure', 'wakeful', 'ascendence', 'serious-minded', 'operate', 'argus-eyed', 'train', 'ascendancy', 'paying_attention', 'hold_in', 'responsible', 'dominance', 'responsible_for', 'see', 'get_up', 'curb', 'see_to_it', 'restraint', 'thoughtful', 'coordinate', 'mastery']
# /////////////////////////////////////////////////////////////////////////
#
#
# Imaginative :-
# These are synonyms =  {'upbeat', 'pollyannaish', 'cheerful'}
#
#
#
#
# Insightful :-
# These are synonyms =  {'mixer', 'social', 'sociable'}
#
#
#
#
# Curious :-
# These are synonyms =  {'chatty', 'blabby', 'bigmouthed', 'blabbermouthed', 'loquacious', 'gabby', 'talky', 'expansive', 'talkative', 'garrulous'}
#
#
#
#
# Creative :-
# These are synonyms =  {'assertive', 'self-assertive', 'self-asserting'}
#
#
#
#
# Outspoken :-
# These are synonyms =  {'outgo', 'surpass', 'outperform', 'surmount', 'exceed', 'outgoing', 'outdo', 'outstrip', 'forthcoming', 'extroverted', 'outmatch'}
#
#
#
#
# Straightforward :-
# These are synonyms =  {'energetic', 'industrious', 'up-and-coming', 'gumptious'}
#
#
#
#
# Direct :-
# These are synonyms =  {'extravert', 'extravertive', 'extraverted', 'extrovertive', 'outgoing', 'forthcoming', 'extrospective', 'extrovert', 'extroverted'}
#
#
#
#
# Receptive :-
# These are synonyms =  {'friendly', 'favorable', 'well-disposed'}
#
#
#
#
# Open-minded :-
# These are synonyms =  {'enthusiastic'}
#
#
#
#
# Adventurous :-
# These are synonyms =  {'point-blank', 'plainspoken', 'outspoken', 'candid', 'frank', 'straight-from-the-shoulder', 'vocal', 'blunt', 'free-spoken', 'forthright'}
#
#
# /////////////////////////////////////////////////////////////////////////
# this is Extraversion  synonyms set: ['outgo', 'chatty', 'extravert', 'enthusiastic', 'blabbermouthed', 'candid', 'mixer', 'extrovertive', 'self-asserting', 'straight-from-the-shoulder', 'garrulous', 'outmatch', 'industrious', 'assertive', 'favorable', 'cheerful', 'bigmouthed', 'extraverted', 'outperform', 'loquacious', 'surmount', 'outgoing', 'blunt', 'expansive', 'sociable', 'extrospective', 'extrovert', 'extroverted', 'up-and-coming', 'social', 'surpass', 'extravertive', 'well-disposed', 'gabby', 'exceed', 'outdo', 'energetic', 'pollyannaish', 'forthcoming', 'free-spoken', 'point-blank', 'plainspoken', 'self-assertive', 'outspoken', 'frank', 'friendly', 'talky', 'outstrip', 'upbeat', 'vocal', 'talkative', 'forthright', 'blabby', 'gumptious']
# /////////////////////////////////////////////////////////////////////////
#
#
# Imaginative :-
# These are synonyms =  {'trustworthy', 'trusty'}
#
#
#
#
# Insightful :-
# These are synonyms =  {'selflessness', 'altruism'}
#
#
#
#
# Curious :-
# These are synonyms =  {'variety', 'genial', 'kind', 'sort', 'tolerant', 'form'}
#
#
#
#
# Creative :-
# These are synonyms =  {'affectionate', 'fond', 'tender', 'lovesome', 'warm'}
#
#
#
#
# Outspoken :-
# These are synonyms =  {'conjunctive', 'co-op', 'accommodative', 'cooperative', 'concerted', 'conjunct'}
#
#
#
#
# Straightforward :-
# These are synonyms =  {'empathic', 'empathetic'}
#
#
#
#
# Direct :-
# These are synonyms =  {'low', 'modest', 'pocket-size', 'minor', 'lowly', 'mild', 'humble', 'pocket-sized', 'small-scale', 'meek', 'small'}
#
#
#
#
# Receptive :-
# These are synonyms =  {'benevolent', 'openhearted', 'likable', 'good-hearted', 'appealing', 'likeable', 'harmonic', 'charitable', 'large-hearted', 'kindly', 'sympathetic'}
#
#
#
#
# Open-minded :-
# These are synonyms =  {'compliant'}
#
#
#
#
# Adventurous :-
# These are synonyms =  set()
#
#
# /////////////////////////////////////////////////////////////////////////
# this is Agreeableness  synonyms set: ['tolerant', 'benevolent', 'fond', 'minor', 'humble', 'appealing', 'accommodative', 'pocket-sized', 'kind', 'charitable', 'kindly', 'empathetic', 'lovesome', 'conjunct', 'low', 'mild', 'genial', 'good-hearted', 'likeable', 'altruism', 'meek', 'form', 'empathic', 'affectionate', 'tender', 'co-op', 'selflessness', 'likable', 'cooperative', 'sort', 'large-hearted', 'concerted', 'sympathetic', 'conjunctive', 'modest', 'compliant', 'openhearted', 'pocket-size', 'lowly', 'variety', 'trusty', 'harmonic', 'small-scale', 'trustworthy', 'warm', 'small']
# /////////////////////////////////////////////////////////////////////////
#
#
# Imaginative :-
# These are synonyms =  {'calm', 'settle_down', 'tranquilize', 'simmer_down', 'unagitated', 'calmness', 'steady', 'becalm', 'chill_out', 'still', 'lull', 'serene', 'quiet', 'sedate', 'composure', 'calm_air', 'cool_it', 'tranquillise', 'quieten', 'tranquil', 'calm_down', 'cool_off', 'tranquillize', 'equanimity'}
#
#
#
#
# Insightful :-
# These are synonyms =  set()
#
#
#
#
# Curious :-
# These are synonyms =  {'gather', 'garner', 'self-possessed', 'self-collected', 'gathered', 'pick_up', 'pull_together', 'poised', 'accumulate', 'collect', 'compile', 'pile_up', 'collected', 'equanimous', 'call_for', 'gather_up', 'self-contained', 'hoard', 'take_in', 'roll_up', 'amass', 'pull_in'}
#
#
#
#
# Creative :-
# These are synonyms =  {'equilibrise', 'balance', 'equilibrate', 'equilibrize', 'balanced', 'poise'}
#
#
#
#
# Outspoken :-
# These are synonyms =  {'peaceable', 'peaceful', 'passive'}
#
#
#
#
# Straightforward :-
# These are synonyms =  {'serene', 'tranquil', 'smooth', 'quiet', 'calm', 'unruffled', 'unagitated', 'still', 'placid'}
#
#
#
#
# Direct :-
# These are synonyms =  {'strong-willed', 'strong-minded'}
#
#
#
#
# Receptive :-
# These are synonyms =  set()
#
#
#
#
# Open-minded :-
# These are synonyms =  {'serene', 'calm', 'tranquil', 'unagitated'}
#
#
#
#
# Adventurous :-
# These are synonyms =  {'bouncy', 'resilient', 'live', 'lively', 'springy'}
#
#
# /////////////////////////////////////////////////////////////////////////
# this is Neuroticism  synonyms set: ['gather', 'garner', 'self-possessed', 'self-collected', 'calm', 'settle_down', 'tranquilize', 'gathered', 'pick_up', 'balance', 'unagitated', 'simmer_down', 'pull_together', 'poised', 'accumulate', 'collect', 'calmness', 'compile', 'pile_up', 'peaceful', 'springy', 'steady', 'collected', 'becalm', 'chill_out', 'strong-minded', 'still', 'equanimous', 'equilibrize', 'call_for', 'passive', 'gather_up', 'peaceable', 'lull', 'serene', 'equilibrise', 'resilient', 'quiet', 'smooth', 'self-contained', 'sedate', 'hoard', 'unruffled', 'live', 'composure', 'calm_air', 'lively', 'balanced', 'cool_it', 'tranquillise', 'poise', 'quieten', 'tranquil', 'bouncy', 'calm_down', 'take_in', 'cool_off', 'strong-willed', 'roll_up', 'amass', 'equilibrate', 'tranquillize', 'placid', 'pull_in', 'equanimity']
# /////////////////////////////////////////////////////////////////////////

# %%
# dataset2 = pd.DataFrame(column_names, columns=["Openness", "Conscintiousness","Extraversion", "Agreeableness", "Neuroticism"])
  
# dataset2

dataset2 = pd.DataFrame.from_dict(column_names, orient='index')
dataset2 = dataset2.transpose()

dataset2.to_csv('Enhanced_ocean_traits')
dataset2
# Out:
#        Openness Conscintiousness    Extraversion Agreeableness     Neuroticism
# 0         place        organised           outgo      tolerant          gather
# 1           odd       controller          chatty    benevolent          garner
# 2        candid         moderate       extravert          fond  self-possessed
# 3   orchestrate        condition    enthusiastic         minor  self-collected
# 4      creative       ascendency  blabbermouthed        humble            calm
# ..          ...              ...             ...           ...             ...
# 68          NaN        see_to_it             NaN           NaN             NaN
# 69          NaN        restraint             NaN           NaN             NaN
# 70          NaN       thoughtful             NaN           NaN             NaN
# 71          NaN       coordinate             NaN           NaN             NaN
# 72          NaN          mastery             NaN           NaN             NaN
#
# [73 rows x 5 columns]
